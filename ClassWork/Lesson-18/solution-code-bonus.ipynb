# %%
import numpy as np
import pandas as pd

#tools to help with JSON
import json
from pandas.io.json import json_normalize
#pprint - pretty print - preserves formatting
from pprint import pprint

#urllib / requests - used commonly for apis
import requests
import urllib2

# %% [markdown]
# # APIs
# - https://www.yelp.com/developers/documentation
# - http://www.reddit.com/dev/api
# - http://www.publicapis.com
# - https://apps.twitter.com (OAUTH nightmares)
# - http://developer.rottentomatoes.com/docs
# - http://developer.nytimes.com/

# %% [markdown]
# ### Wikipedia

# %% [markdown]
# - https://en.wikipedia.org/w/api.php?action=help&modules=main (API documentation)
# - https://en.wikipedia.org/w/api.php?action=help&modules=query (more documentation)
# - https://en.wikipedia.org/w/api.php?action=help&modules=query%2Bextracts (Returns plain-text or limited HTML extracts of the given pages)

# %% [markdown]
# #Example: NY Times contributions example

# %% [markdown]
# ## Using a web api
# - Everything after the '?' is called the query string, '&' denotes variables
# - API-Key is provided by the api owner and should not be shared (typically)
#
# http://api.nytimes.com/svc/elections/us/v3/finances/2012/contributions/candidate/P80003338.json?api-key=a135ff57e67e72c98171ea7a99d92d5b%3A8%3A72904630"

# %% [markdown]
# ### API Call

# %% [markdown]
# ### Let's build our call
# NY Times api has a handy query builder that can help us get started using their api.
# http://developer.nytimes.com/io-docs

# %%
website = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=2c3cd35f0e301971ca704c014eb24ce1%3A4%3A45521562")
website.headers
# Out:
# {'Content-Length': '25249', 'X-Powered-By': 'PHP/5.3.27', 'Vary': 'Accept-Encoding', 'Server': 'nginx/1.4.1', 'Access-Control-Allow-Credentials': 'true', 'Date': 'Tue, 22 Mar 2016 19:31:15 GMT', 'X-Mashery-Responder': 'prod-j-worker-atl-04.mashery.com', 'X-Cached': 'MISS', 'Content-Type': 'application/json; charset=UTF-8', 'Access-Control-Allow-Origin': '*'}

# %% [markdown]
# Info on website status can be found here: http://www.w3.org/Protocols/rfc2616/rfc2616-sec10.html

# %% [markdown]
# ## JSON

# %% [markdown]
# - javascript object notation
# - comporable to xml
# - structured information

# %%
website.json()
# Out:
# {u'copyright': u'Copyright (c) 2013 The New York Times Company.  All Rights Reserved.',
#  u'response': {u'docs': [{u'_id': u'56c397f3798810739a21368a',
#     u'abstract': u"James Poniewozik Critic's Notebook observes difficulty comedians are having in satirizing Donald J Trump, presidential candidate who has attitude of insult comic.",
#     u'blog': [],
#     u'byline': {u'original': u'By JAMES PONIEWOZIK',
#      u'person': [{u'firstname': u'James',
#        u'lastname': u'PONIEWOZIK',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Donald Trump Is a Conundrum for Political Comedy',
#      u'print_headline': u'Comedians, Like Rivals, Find Trump to Be a Difficult Target'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Trump, Donald J'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Comedy and Humor'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Presidential Election of 2016'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Television'},
#      {u'is_major': u'N',
#       u'name': u'creative_works',
#       u'rank': u'6',
#       u'value': u"Triumph's Election Special 2016 (TV Program)"},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'7',
#       u'value': u'Smigel, Robert'}],
#     u'lead_paragraph': u'Mr. Trump\u2019s over-the-top ways have made him almost too easy to mock as a presidential candidate.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/02/17/arts/17LATENIGHTJP1/17LATENIGHTJP1-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/02/17/arts/17LATENIGHTJP1/17LATENIGHTJP1-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2016/02/17/arts/17LATENIGHTJP1/17LATENIGHTJP1-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/02/17/arts/17LATENIGHTJP1/17LATENIGHTJP1-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/02/17/arts/17LATENIGHTJP1/17LATENIGHTJP1-thumbStandard-v2.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/02/17/arts/17LATENIGHTJP1/17LATENIGHTJP1-thumbStandard-v2.jpg',
#       u'width': 75}],
#     u'news_desk': u'Culture',
#     u'print_page': u'4',
#     u'pub_date': u'2016-02-17T00:00:00Z',
#     u'section_name': u'Arts',
#     u'slideshow_credits': None,
#     u'snippet': u'Mr. Trump\u2019s over-the-top ways have made him almost too easy to mock as a presidential candidate.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Television',
#     u'type_of_material': u'Review',
#     u'web_url': u'http://www.nytimes.com/2016/02/17/arts/television/donald-trump-is-a-conundrum-for-political-comedy.html',
#     u'word_count': u'1330'},
#    {u'_id': u'55a6b3ec7988102dbd7885b3',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'organization': u'The New York Times',
#      u'original': u'By THE NEW YORK TIMES',
#      u'person': []},
#     u'document_type': u'multimedia',
#     u'headline': {u'main': u'Which Presidential Candidates Are Winning the Money Race'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Campaign Finance'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Presidential Election of 2016'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Political Action Committees'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'4',
#       u'value': u'Federal Election Commission'}],
#     u'lead_paragraph': u'See how the latest fund-raising numbers from the campaigns and outside groups stack up.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/08/01/us/elections/election-2016-campaign-money-race-1438468879112/election-2016-campaign-money-race-1438468879112-thumbWide-v8.png',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/08/01/us/elections/election-2016-campaign-money-race-1438468879112/election-2016-campaign-money-race-1438468879112-thumbWide-v8.png',
#       u'width': 190},
#      {u'height': 375,
#       u'legacy': {u'xlarge': u'images/2015/08/01/us/elections/election-2016-campaign-money-race-1438468879112/election-2016-campaign-money-race-1438468879112-articleLarge-v8.png',
#        u'xlargeheight': u'375',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/08/01/us/elections/election-2016-campaign-money-race-1438468879112/election-2016-campaign-money-race-1438468879112-articleLarge-v8.png',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/08/01/us/elections/election-2016-campaign-money-race-1438468879112/election-2016-campaign-money-race-1438468879112-thumbStandard-v8.png',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/08/01/us/elections/election-2016-campaign-money-race-1438468879112/election-2016-campaign-money-race-1438468879112-thumbStandard-v8.png',
#       u'width': 75}],
#     u'news_desk': u'U.S. / Election 2016',
#     u'print_page': None,
#     u'pub_date': u'2016-02-22T13:00:44Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'See how the latest fund-raising numbers from the campaigns and outside groups stack up.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Election 2016',
#     u'type_of_material': u'Interactive Feature',
#     u'web_url': u'http://www.nytimes.com/interactive/2016/us/elections/election-2016-campaign-money-race.html',
#     u'word_count': None},
#    {u'_id': u'56e53a377988101860ab281e',
#     u'abstract': u'Release schedules of movie studios reveal number of films that will likely have political undertones and figure in political conversation in final months of 2016 presidential election.',
#     u'blog': [],
#     u'byline': {u'original': u'By MICHAEL CIEPLY',
#      u'person': [{u'firstname': u'Michael',
#        u'lastname': u'CIEPLY',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Politics Invades Hollywood',
#      u'print_headline': u'Hollywood Invaded by Politics  From Every Point of View'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Movies'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Presidential Election of 2016'},
#      {u'is_major': u'N',
#       u'name': u'creative_works',
#       u'rank': u'3',
#       u'value': u'The Purge: Election Year (Movie)'},
#      {u'is_major': u'N',
#       u'name': u'creative_works',
#       u'rank': u'4',
#       u'value': u'The Founder (Movie)'},
#      {u'is_major': u'N',
#       u'name': u'creative_works',
#       u'rank': u'5',
#       u'value': u'Southside With You (Movie)'},
#      {u'is_major': u'N',
#       u'name': u'creative_works',
#       u'rank': u'9',
#       u'value': u'The Birth of a Nation (Movie)'}],
#     u'lead_paragraph': u'In an election year, the only real \u201cOctober surprise\u201d from Hollywood would be a complete political blackout. But don\u2019t worry. It won\u2019t happen.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/03/12/business/14polifilm1/14polifilm1-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/03/12/business/14polifilm1/14polifilm1-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 250,
#       u'legacy': {u'xlarge': u'images/2016/03/12/business/14polifilm1/14polifilm1-articleLarge.jpg',
#        u'xlargeheight': u'250',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/03/12/business/14polifilm1/14polifilm1-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/03/12/business/14polifilm1/14polifilm1-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/03/12/business/14polifilm1/14polifilm1-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Business',
#     u'print_page': u'1',
#     u'pub_date': u'2016-03-14T00:00:00Z',
#     u'section_name': u'Business Day',
#     u'slideshow_credits': None,
#     u'snippet': u'In an election year, the only real \u201cOctober surprise\u201d from Hollywood would be a complete political blackout. But don\u2019t worry. It won\u2019t happen.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Media',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/03/14/business/media/politics-invade-hollywood.html',
#     u'word_count': u'1378'},
#    {u'_id': u'56d460247988107c6d9ab625',
#     u'abstract': u'The amount \u2014 a huge sum for a candidate who has virtually no donors giving the largest contributions legally permitted \u2014 suggests that Senator Bernie Sanders successfully capitalized on his close finish in the Iowa caucuses behind Hillary Clinton and his victory in the New Hampshire primary.',
#     u'blog': [],
#     u'byline': {u'original': u'By NICHOLAS CONFESSORE',
#      u'person': [{u'firstname': u'Nicholas',
#        u'lastname': u'CONFESSORE',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'blogpost',
#     u'headline': {u'kicker': u'First Draft',
#      u'main': u'Bernie Sanders Collects $36 Million in February as Fund-Raising Successes Continue'},
#     u'keywords': [{u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Clinton, Hillary Rodham'},
#      {u'name': u'persons', u'rank': u'2', u'value': u'Sanders, Bernard'},
#      {u'name': u'organizations', u'rank': u'1', u'value': u'Democratic Party'},
#      {u'name': u'organizations',
#       u'rank': u'2',
#       u'value': u'Federal Election Commission'},
#      {u'name': u'subject', u'rank': u'1', u'value': u'Campaign Finance'},
#      {u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Presidential Election of 2016'},
#      {u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Primaries and Caucuses'}],
#     u'lead_paragraph': None,
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/02/29/us/29firstdraft-sanders1/29firstdraft-sanders1-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/02/29/us/29firstdraft-sanders1/29firstdraft-sanders1-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2016/02/29/us/29firstdraft-sanders1/29firstdraft-sanders1-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/02/29/us/29firstdraft-sanders1/29firstdraft-sanders1-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/02/29/us/29firstdraft-sanders1/29firstdraft-sanders1-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/02/29/us/29firstdraft-sanders1/29firstdraft-sanders1-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Politics',
#     u'print_page': None,
#     u'pub_date': u'2016-02-29T10:11:56Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'The amount \u2014 a huge sum for a candidate who has virtually no donors giving the largest contributions legally permitted \u2014 suggests that Senator Bernie Sanders successfully capitalized on his close finish in the Iowa caucuses behind Hillary Clinton...',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'Blog',
#     u'web_url': u'http://www.nytimes.com/politics/first-draft/2016/02/29/bernie-sanders-collects-36-million-in-february-as-fund-raising-successes-continue/',
#     u'word_count': u'249'},
#    {u'_id': u'56b9125a79881038a87bfe82',
#     u'abstract': u'A voter-turnout tactic employed by Ted Cruz\u2019s presidential campaign in Iowa is cropping up in New Hampshire, by way of an organization about which few public details are available.',
#     u'blog': [],
#     u'byline': {u'original': u'By NICHOLAS CONFESSORE',
#      u'person': [{u'firstname': u'Nicholas',
#        u'lastname': u'CONFESSORE',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'blogpost',
#     u'headline': {u'kicker': u'First Draft',
#      u'main': u'&#8216;Voter-Shaming&#8217; Mailer That Made Noise in Iowa Shows Up in New Hampshire',
#      u'print_headline': u'Mailing That Drew Fire in Iowa Shows Up in New Hampshire'},
#     u'keywords': [{u'name': u'persons', u'rank': u'1', u'value': u'Cruz, Ted'},
#      {u'name': u'glocations', u'rank': u'1', u'value': u'Iowa'},
#      {u'name': u'glocations', u'rank': u'2', u'value': u'New Hampshire'},
#      {u'name': u'organizations',
#       u'rank': u'1',
#       u'value': u'Federal Election Commission'},
#      {u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Presidential Election of 2016'},
#      {u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Voter Registration and Requirements'}],
#     u'lead_paragraph': None,
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/02/08/us/politics/08firstdraft-shame/08firstdraft-shame-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/02/08/us/politics/08firstdraft-shame/08firstdraft-shame-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2016/02/08/us/politics/08firstdraft-shame/08firstdraft-shame-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/02/08/us/politics/08firstdraft-shame/08firstdraft-shame-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/02/08/us/politics/08firstdraft-shame/08firstdraft-shame-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/02/08/us/politics/08firstdraft-shame/08firstdraft-shame-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Politics',
#     u'print_page': None,
#     u'pub_date': u'2016-02-08T17:09:47Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'A voter-turnout tactic employed by Ted Cruz\u2019s presidential campaign in Iowa is cropping up in New Hampshire, by way of an organization about which few public details are available.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'Blog',
#     u'web_url': u'http://www.nytimes.com/politics/first-draft/2016/02/08/voter-shaming-mailer-that-made-noise-in-iowa-shows-up-in-new-hampshire/',
#     u'word_count': u'387'},
#    {u'_id': u'547949227988105199668a03',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'original': u'By FRAN SILVERMAN',
#      u'person': [{u'firstname': u'Fran',
#        u'lastname': u'SILVERMAN',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'content_kicker': u'The Election',
#      u'kicker': u'The Election',
#      u'main': u'Economy Is Voters\u2019 Top Worry, but Agreement Stops There',
#      u'print_headline': u'Economy Voters\u2019 Top Worry, But Agreement Stops There',
#      u'seo': u'Economy Is Voters\u2019 No. 1 Concern, but Agreement Stops There'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Voter Registration and Requirements'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Presidential Election of 2008'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'United States Economy'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'4',
#       u'value': u'Connecticut'}],
#     u'lead_paragraph': u'Voters around Connecticut expressed similar concerns about the deteriorating economy with two weeks to go before the presidential election.',
#     u'multimedia': [{u'height': 361,
#       u'legacy': {u'xlarge': u'images/2008/10/26/nyregion/26voicesct_600.jpg',
#        u'xlargeheight': u'361',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2008/10/26/nyregion/26voicesct_600.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2008/10/26/nyregion/26voicesct_75.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2008/10/26/nyregion/26voicesct_75.jpg',
#       u'width': 75}],
#     u'news_desk': u'Regionals',
#     u'print_page': u'1',
#     u'pub_date': u'2008-10-26T00:00:00Z',
#     u'section_name': u'N.Y. / Region',
#     u'slideshow_credits': None,
#     u'snippet': u'Voters around Connecticut expressed similar concerns about the deteriorating economy with two weeks to go before the presidential election.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Connecticut',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2008/10/26/nyregion/connecticut/26voicesct.html',
#     u'word_count': u'1461'},
#    {u'_id': u'56ca06ef7988100e95e43f57',
#     u'abstract': u"Outsider presidential candidates Sen Ted Cruz and Donald J Trump are currently best-financed in field, despite Republican Party establishment's effort to fund a nominee with more traditional appeal; donors scramble to determine which super PACs and remaining candidates offer best challenge to Trump and Cruz.",
#     u'blog': [],
#     u'byline': {u'contributor': u'Maggie Haberman, Rachel Shorey and Thomas Kaplan contributed reporting.',
#      u'original': u'By NICHOLAS CONFESSORE and SARAH COHEN',
#      u'person': [{u'firstname': u'Nicholas',
#        u'lastname': u'CONFESSORE',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'},
#       {u'firstname': u'Sarah',
#        u'lastname': u'COHEN',
#        u'organization': u'',
#        u'rank': 2,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Ted Cruz and Donald Trump Head Toward Super Tuesday With G.O.P.\u2019s Deepest Pockets',
#      u'print_headline': u'Cruz and Trump Head Toward Super Tuesday With G.O.P.&#8217;s Deepest Pockets '},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Presidential Election of 2016'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'11',
#       u'value': u'Rubio, Marco'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'12',
#       u'value': u'Kasich, John R'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Campaign Finance'},
#      {u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'3',
#       u'value': u'Cruz, Ted'},
#      {u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'4',
#       u'value': u'Trump, Donald J'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'United States Politics and Government'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'6',
#       u'value': u'Political Action Committees'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'7',
#       u'value': u'Bush, Jeb'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'8',
#       u'value': u'Federal Election Commission'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'9',
#       u'value': u'Republican Party'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'10',
#       u'value': u'Democratic Party'}],
#     u'lead_paragraph': u'The two insurgent candidates appear to be in the best position financially to compete in an expensive stage of the campaign: the day when twelve states vote at once.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/02/22/us/politics/22donors1/22donors1-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/02/22/us/politics/22donors1/22donors1-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 401,
#       u'legacy': {u'xlarge': u'images/2016/02/22/us/politics/22donors1/22donors1-articleLarge.jpg',
#        u'xlargeheight': u'401',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/02/22/us/politics/22donors1/22donors1-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/02/22/us/politics/22donors1/22donors1-thumbStandard-v2.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/02/22/us/politics/22donors1/22donors1-thumbStandard-v2.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': u'12',
#     u'pub_date': u'2016-02-22T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'The two insurgent candidates appear to be in the best position financially to compete in an expensive stage of the campaign: the day when twelve states vote at once.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/02/22/us/politics/ted-cruz-and-donald-trump-have-deepest-pockets-ahead-of-super-tuesday.html',
#     u'word_count': u'1124'},
#    {u'_id': u'56b555cd79881030baa2502b',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'contributor': u'Nicholas Confessore reported from Manchester, and Sarah Cohen from New York. Maggie Haberman and Jeremy B. Merrill contributed reporting from New York.',
#      u'original': u'By NICHOLAS CONFESSORE and SARAH COHEN',
#      u'person': [{u'firstname': u'Nicholas',
#        u'lastname': u'CONFESSORE',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'},
#       {u'firstname': u'Sarah',
#        u'lastname': u'COHEN',
#        u'organization': u'',
#        u'rank': 2,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Donald Trump\u2019s Campaign, Billed as Self-Funded, Risks Little of His Fortune',
#      u'print_headline': u'Trump\u2019s Bid Is Going Easy on His Wallet'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Presidential Election of 2016'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'2',
#       u'value': u'Trump, Donald J'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Campaign Finance'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Political Action Committees'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'5',
#       u'value': u'Federal Election Commission'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'6',
#       u'value': u'Trump Organization'}],
#     u'lead_paragraph': u'Mr. Trump\u2019s White House run blurs the line between campaigning and brand-building and complicates his claims that he is funding his own campaign.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/02/06/us/06trumpdonors-web1/06trumpdonors-web1-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/02/06/us/06trumpdonors-web1/06trumpdonors-web1-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2016/02/06/us/06trumpdonors-web1/06trumpdonors-web1-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/02/06/us/06trumpdonors-web1/06trumpdonors-web1-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/02/06/us/06trumpdonors-web1/06trumpdonors-web1-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/02/06/us/06trumpdonors-web1/06trumpdonors-web1-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'National',
#     u'print_page': u'1',
#     u'pub_date': u'2016-02-06T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'slideshow_credits': None,
#     u'snippet': u'Mr. Trump\u2019s White House run blurs the line between campaigning and brand-building and complicates his claims that he is funding his own campaign.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Politics',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/02/06/us/politics/donald-trumps-campaign-billed-as-self-funded-risks-little-of-his-fortune.html',
#     u'word_count': u'1461'},
#    {u'_id': u'4fc2857645c1498b0d6d0e99',
#     u'abstract': u'Eichler, A: Election by Murder',
#     u'blog': [],
#     u'byline': {u'original': u'I.A',
#      u'person': [{u'firstname': u'I.',
#        u'lastname': u'',
#        u'middlename': u'A',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'President-Maker; ELECTION BY MURDER. By Alfred Eichler. 224 pp. New York: Lantern Press. $2.'},
#     u'keywords': [{u'name': u'creative_works',
#       u'value': u'ELECTION BY MURDER'},
#      {u'name': u'creative_works', u'value': u'ELECTION BY MURDER'},
#      {u'name': u'persons', u'value': u'EICHLER, A'},
#      {u'name': u'persons', u'value': u'EICHLER, A'},
#      {u'name': u'subject', u'value': u'BOOKS AND LITERATURE'},
#      {u'name': u'subject', u'value': u'REVIEWS'},
#      {u'name': u'subject', u'value': u'BOOKS AND LITERATURE'},
#      {u'name': u'subject', u'value': u'REVIEWS'}],
#     u'lead_paragraph': None,
#     u'multimedia': [],
#     u'news_desk': None,
#     u'print_page': u'BR21',
#     u'pub_date': u'1947-06-15T00:00:00Z',
#     u'section_name': None,
#     u'slideshow_credits': None,
#     u'snippet': u'Eichler, A: Election by Murder',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'Review',
#     u'web_url': u'http://query.nytimes.com/gst/abstract.html?res=9906E6DF113EE13BBC4D52DFB066838C659EDE',
#     u'word_count': 142},
#    {u'_id': u'569d188f7988100a3479e71b',
#     u'abstract': u"Afghan officials condemn election commission's plan to hold parliamentary and local elections in October 2016, calling it illegitimate; government asserts it was bypassed and cites planned electoral reforms which have yet to go into effect; critics claim countering Taliban insurgency requires credibility only fresh government can offer.",
#     u'blog': [],
#     u'byline': {u'contributor': u'David Jolly and Ahmad Shakib contributed reporting.',
#      u'original': u'By MUJIB MASHAL',
#      u'person': [{u'firstname': u'Mujib',
#        u'lastname': u'MASHAL',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Afghan Panel Sets Election Date, Drawing Government Criticism',
#      u'print_headline': u'Afghan Commission Sets Election Date'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'1',
#       u'value': u'Afghanistan'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Elections'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'3',
#       u'value': u'Ghani, Ashraf'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'4',
#       u'value': u'Independent Election Commission (Afghanistan)'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'5',
#       u'value': u'Abdullah, Abdullah'}],
#     u'lead_paragraph': u'A spokesman for the government\u2019s chief executive, Abdullah Abdullah, denounced the Oct. 15 date because the electoral reform Mr. Abdullah had called for had not happened.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2016/01/19/world/19Afghanistan-web2/19Afghanistan-web2-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2016/01/19/world/19Afghanistan-web2/19Afghanistan-web2-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2016/01/19/world/19Afghanistan-web2/19Afghanistan-web2-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2016/01/19/world/19Afghanistan-web2/19Afghanistan-web2-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2016/01/19/world/19Afghanistan-web2/19Afghanistan-web2-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2016/01/19/world/19Afghanistan-web2/19Afghanistan-web2-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Foreign',
#     u'print_page': u'8',
#     u'pub_date': u'2016-01-19T00:00:00Z',
#     u'section_name': u'World',
#     u'slideshow_credits': None,
#     u'snippet': u'A spokesman for the government\u2019s chief executive, Abdullah Abdullah, denounced the Oct. 15 date because the electoral reform Mr. Abdullah had called for had not happened.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Asia Pacific',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2016/01/19/world/asia/afghan-panel-sets-election-date-drawing-government-criticism.html',
#     u'word_count': u'746'}],
#   u'meta': {u'hits': 737786, u'offset': 0, u'time': 42}},
#  u'status': u'OK'}

# %% [markdown]
# ### Using the urllib2 to convert to a dataframe

# %%
request=urllib2.Request("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=2c3cd35f0e301971ca704c014eb24ce1%3A4%3A45521562")
response = urllib2.urlopen(request)
elevations = response.read()
data1 = json.loads(elevations)
print type(data)
data= data1['response']
# Out:
# <type 'dict'>

# %%
pres_df = json_normalize(data['docs'])
pres_df.head()
pres_df.describe
# Out:
# <bound method DataFrame.describe of                         _id  \
# 0  56c397f3798810739a21368a
# 1  55a6b3ec7988102dbd7885b3
# 2  56e53a377988101860ab281e
# 3  56d460247988107c6d9ab625
# 4  56b9125a79881038a87bfe82
# 5  547949227988105199668a03
# 6  56ca06ef7988100e95e43f57
# 7  56b555cd79881030baa2502b
# 8  4fc2857645c1498b0d6d0e99
# 9  569d188f7988100a3479e71b
#
#                                             abstract blog  \
# 0  James Poniewozik Critic's Notebook observes di...   []
# 1                                               None   []
# 2  Release schedules of movie studios reveal numb...   []
# 3  The amount — a huge sum for a candidate who ha...   []
# 4  A voter-turnout tactic employed by Ted Cruz’s ...   []
# 5                                               None   []
# 6  Outsider presidential candidates Sen Ted Cruz ...   []
# 7                                               None   []
# 8                     Eichler, A: Election by Murder   []
# 9  Afghan officials condemn election commission's...   []
#
#                                   byline.contributor byline.organization  \
# 0                                                NaN                 NaN
# 1                                                NaN  The New York Times
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
# 5                                                NaN                 NaN
# 6  Maggie Haberman, Rachel Shorey and Thomas Kapl...                 NaN
# 7  Nicholas Confessore reported from Manchester, ...                 NaN
# 8                                                NaN                 NaN
# 9  David Jolly and Ahmad Shakib contributed repor...                 NaN
#
#                           byline.original  \
# 0                     By JAMES PONIEWOZIK
# 1                   By THE NEW YORK TIMES
# 2                       By MICHAEL CIEPLY
# 3                  By NICHOLAS CONFESSORE
# 4                  By NICHOLAS CONFESSORE
# 5                       By FRAN SILVERMAN
# 6  By NICHOLAS CONFESSORE and SARAH COHEN
# 7  By NICHOLAS CONFESSORE and SARAH COHEN
# 8                                     I.A
# 9                         By MUJIB MASHAL
#
#                                        byline.person document_type  \
# 0  [{u'organization': u'', u'role': u'reported', ...       article
# 1                                                 []    multimedia
# 2  [{u'organization': u'', u'role': u'reported', ...       article
# 3  [{u'organization': u'', u'role': u'reported', ...      blogpost
# 4  [{u'organization': u'', u'role': u'reported', ...      blogpost
# 5  [{u'organization': u'', u'role': u'reported', ...       article
# 6  [{u'organization': u'', u'role': u'reported', ...       article
# 7  [{u'organization': u'', u'role': u'reported', ...       article
# 8  [{u'firstname': u'I.', u'middlename': u'A', u'...       article
# 9  [{u'organization': u'', u'role': u'reported', ...       article
#
#   headline.content_kicker headline.kicker    ...     print_page  \
# 0                     NaN             NaN    ...              4
# 1                     NaN             NaN    ...           None
# 2                     NaN             NaN    ...              1
# 3                     NaN     First Draft    ...           None
# 4                     NaN     First Draft    ...           None
# 5            The Election    The Election    ...              1
# 6                     NaN             NaN    ...             12
# 7                     NaN             NaN    ...              1
# 8                     NaN             NaN    ...           BR21
# 9                     NaN             NaN    ...              8
#
#                pub_date   section_name slideshow_credits  \
# 0  2016-02-17T00:00:00Z           Arts              None
# 1  2016-02-22T13:00:44Z           U.S.              None
# 2  2016-03-14T00:00:00Z   Business Day              None
# 3  2016-02-29T10:11:56Z           U.S.              None
# 4  2016-02-08T17:09:47Z           U.S.              None
# 5  2008-10-26T00:00:00Z  N.Y. / Region              None
# 6  2016-02-22T00:00:00Z           U.S.              None
# 7  2016-02-06T00:00:00Z           U.S.              None
# 8  1947-06-15T00:00:00Z           None              None
# 9  2016-01-19T00:00:00Z          World              None
#
#                                              snippet              source  \
# 0  Mr. Trump’s over-the-top ways have made him al...  The New York Times
# 1  See how the latest fund-raising numbers from t...  The New York Times
# 2  In an election year, the only real “October su...  The New York Times
# 3  The amount — a huge sum for a candidate who ha...  The New York Times
# 4  A voter-turnout tactic employed by Ted Cruz’s ...  The New York Times
# 5  Voters around Connecticut expressed similar co...  The New York Times
# 6  The two insurgent candidates appear to be in t...  The New York Times
# 7  Mr. Trump’s White House run blurs the line bet...  The New York Times
# 8                     Eichler, A: Election by Murder  The New York Times
# 9  A spokesman for the government’s chief executi...  The New York Times
#
#   subsection_name     type_of_material  \
# 0      Television               Review
# 1   Election 2016  Interactive Feature
# 2           Media                 News
# 3        Politics                 Blog
# 4        Politics                 Blog
# 5     Connecticut                 News
# 6        Politics                 News
# 7        Politics                 News
# 8            None               Review
# 9    Asia Pacific                 News
#
#                                              web_url word_count
# 0  http://www.nytimes.com/2016/02/17/arts/televis...       1330
# 1  http://www.nytimes.com/interactive/2016/us/ele...       None
# 2  http://www.nytimes.com/2016/03/14/business/med...       1378
# 3  http://www.nytimes.com/politics/first-draft/20...        249
# 4  http://www.nytimes.com/politics/first-draft/20...        387
# 5  http://www.nytimes.com/2008/10/26/nyregion/con...       1461
# 6  http://www.nytimes.com/2016/02/22/us/politics/...       1124
# 7  http://www.nytimes.com/2016/02/06/us/politics/...       1461
# 8  http://query.nytimes.com/gst/abstract.html?res...        142
# 9  http://www.nytimes.com/2016/01/19/world/asia/a...        746
#
# [10 rows x 27 columns]>

# %%
pres_df[['abstract', 'byline.original', 'subsection_name']]
# Out:
#                                             abstract  \
# 0  James Poniewozik Critic's Notebook observes di...
# 1                                               None
# 2  Release schedules of movie studios reveal numb...
# 3  The amount — a huge sum for a candidate who ha...
# 4  A voter-turnout tactic employed by Ted Cruz’s ...
# 5                                               None
# 6  Outsider presidential candidates Sen Ted Cruz ...
# 7                                               None
# 8                     Eichler, A: Election by Murder
# 9  Afghan officials condemn election commission's...
#
#                           byline.original subsection_name
# 0                     By JAMES PONIEWOZIK      Television
# 1                   By THE NEW YORK TIMES   Election 2016
# 2                       By MICHAEL CIEPLY           Media
# 3                  By NICHOLAS CONFESSORE        Politics
# 4                  By NICHOLAS CONFESSORE        Politics
# 5                       By FRAN SILVERMAN     Connecticut
# 6  By NICHOLAS CONFESSORE and SARAH COHEN        Politics
# 7  By NICHOLAS CONFESSORE and SARAH COHEN        Politics
# 8                                     I.A            None
# 9                         By MUJIB MASHAL    Asia Pacific

# %% [markdown]
# #Exercise: NY Times movies

# %%
## pull all the movies (use the requests package)
movies = requests.get("http://api.nytimes.com/svc/movies/v2/reviews/all.json?api-key=7acc2215c568722cbb6f1d6a47e747e4%3A9%3A72904630")

# %%
## take a look at the headers
movies.headers
# Out:
# {'Content-Length': '35900', 'Via': '1.1 varnish', 'X-Cache': 'MISS', 'X-Mashery-Responder': 'prod-j-worker-atl-04.mashery.com', 'Age': '0', 'Vary': 'Origin', 'Server': 'nginx/1.4.1', 'Last-Modified': 'Thu, 03 Mar 2016 12:00:06 GMT', 'X-Varnish': '1779286052', 'Cache-Control': 'max-age=7200', 'Date': 'Tue, 22 Mar 2016 19:33:47 GMT', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'GET, PUT, POST', 'Content-Type': 'application/json; charset=UTF-8', 'Accept-Ranges': 'bytes', 'ETag': '"Thu, 03 Mar 2016 12:00:06 GMT"'}

# %%
## rerun the api request with urllib2 andtransform the data to pandas dataframe 
request=urllib2.Request("http://api.nytimes.com/svc/movies/v2/reviews/all.json?api-key=7acc2215c568722cbb6f1d6a47e747e4%3A9%3A72904630")
response = urllib2.urlopen(request)
elevations = response.read()
data = json.loads(elevations)
movies_df = json_normalize(data['results'])
movies_df.describe
# Out:
# <bound method DataFrame.describe of                  byline capsule_review  critics_pick         date_updated  \
# 0       Neil Genzlinger                            1  2016-03-03 07:00:06
# 1        Stephen Holden                            0  2016-02-11 18:53:26
# 2        Manohla Dargis                            0  2016-02-11 07:00:05
# 3        Manohla Dargis                            0  2016-02-04 15:39:06
# 4        Manohla Dargis                            0  2016-02-04 17:33:52
# 5        Ben Kenigsberg                            1  2016-02-05 00:31:10
# 6        Stephen Holden                            0  2016-02-04 17:13:51
# 7       Neil Genzlinger                            0  2016-02-04 17:54:58
# 8       Neil Genzlinger                            0  2016-02-04 17:39:23
# 9        Nicolas Rapold                            0  2016-02-04 17:47:10
# 10  Jeannette Catsoulis                            0  2016-02-04 16:55:21
# 11          A. O. Scott                            1  2016-02-02 23:37:45
# 12         Rachel Saltz                            0  2016-02-02 12:13:34
# 13         Andy Webster                            0  2016-01-29 18:05:58
# 14      Neil Genzlinger                            0  2016-01-28 18:20:58
# 15      Neil Genzlinger                            0  2016-01-28 19:20:51
# 16       Stephen Holden                            0  2016-01-28 07:00:05
# 17          A. O. Scott                            0  2016-01-28 17:53:40
# 18       Daniel M. Gold                            1  2016-01-29 14:02:38
# 19      Neil Genzlinger                            0  2016-01-28 07:00:11
#
#                       display_title dvd_release_date  \
# 0                          Zootopia       0000-00-00
# 1                       Zoolander 2             None
# 2                          Deadpool             None
# 3                     Hail, Caesar!             None
# 4   Pride and Prejudice and Zombies             None
# 5                     Fort Buchanan             None
# 6          Eisenstein in Guanajuato             None
# 7                        Southbound             None
# 8                          The Pack             None
# 9                        Tumbledown             None
# 10                       The Choice             None
# 11                             Rams             None
# 12                    Saala Khadoos             None
# 13            Fifty Shades of Black             None
# 14                        JeruZalem             None
# 15                       Lazer Team             None
# 16                 The Finest Hours             None
# 17              Rabin, The Last Day             None
# 18   Requiem for the American Dream             None
# 19                  Kung Fu Panda 3             None
#
#                                              headline  \
# 0   Review: In ‘Zootopia,’ an Intrepid Bunny Chase...
# 1       Review: In ‘Zoolander 2,’ All Is Still Vanity
# 2   Review: ‘Deadpool,’ a Sardonic Supervillain on...
# 3   Review: In ‘Hail, Caesar!’ the Coens Revisit O...
# 4   Review: ‘Pride and Prejudice and Zombies’; Mor...
# 5     Review: In ‘Fort Buchanan,’ Making Love and War
# 6   Review: ‘Eisenstein in Guanajuato’ Explores 10...
# 7   Review: ‘Southbound’ Tells Five Horror Tales, ...
# 8   Review: ‘The Pack’ Pits a Family Against Vicio...
# 9   Review: In ‘Tumbledown,’ a Book Is the Third P...
# 10  Review: In ‘The Choice,’ a Sudsy Romance That ...
# 11  Review: In ‘Rams,’ Brothers at Odds Face a Sha...
# 12  Review: In ‘Saala Khadoos,’ a Female Boxer Ris...
# 13  Review: ‘Fifty Shades of Black’ Sells Sex With...
# 14       Review: ‘JeruZalem,’ Through Glasses, Darkly
# 15  Review: In ‘Lazer Team,’ Bickering Losers Try ...
# 16  Review: ‘The Finest Hours’ Stars Chris Pine, L...
# 17  Review: Amos Gitai’s ‘Rabin, the Last Day’ Loo...
# 18  Review: Noam Chomsky Focuses on Financial Ineq...
# 19  In ‘Kung Fu Panda 3,’ a New Dad Who Talks Like...
#
#                              link.suggested_link_text link.type  \
# 0          Read the New York Times Review of Zootopia   article
# 1       Read the New York Times Review of Zoolander 2   article
# 2          Read the New York Times Review of Deadpool   article
# 3     Read the New York Times Review of Hail, Caesar!   article
# 4   Read the New York Times Review of Pride and Pr...   article
# 5     Read the New York Times Review of Fort Buchanan   article
# 6   Read the New York Times Review of Eisenstein i...   article
# 7        Read the New York Times Review of Southbound   article
# 8          Read the New York Times Review of The Pack   article
# 9        Read the New York Times Review of Tumbledown   article
# 10       Read the New York Times Review of The Choice   article
# 11             Read the New York Times Review of Rams   article
# 12    Read the New York Times Review of Saala Khadoos   article
# 13  Read the New York Times Review of Fifty Shades...   article
# 14        Read the New York Times Review of JeruZalem   article
# 15       Read the New York Times Review of Lazer Team   article
# 16  Read the New York Times Review of The Finest H...   article
# 17  Read the New York Times Review of Rabin, The L...   article
# 18  Read the New York Times Review of Requiem for ...   article
# 19  Read the New York Times Review of Kung Fu Panda 3   article
#
#                                              link.url      ...       \
# 0   http://movies.nytimes.com/2016/03/04/movies/zo...      ...
# 1   http://movies.nytimes.com/2016/02/12/movies/zo...      ...
# 2   http://movies.nytimes.com/2016/02/12/movies/de...      ...
# 3   http://movies.nytimes.com/2016/02/05/movies/ha...      ...
# 4   http://movies.nytimes.com/2016/02/05/movies/pr...      ...
# 5   http://movies.nytimes.com/2016/02/05/movies/re...      ...
# 6   http://movies.nytimes.com/2016/02/05/movies/ei...      ...
# 7   http://movies.nytimes.com/2016/02/05/movies/so...      ...
# 8   http://movies.nytimes.com/2016/02/05/movies/re...      ...
# 9   http://movies.nytimes.com/2016/02/05/movies/tu...      ...
# 10  http://movies.nytimes.com/2016/02/05/movies/th...      ...
# 11  http://movies.nytimes.com/2016/02/03/movies/re...      ...
# 12  http://movies.nytimes.com/2016/02/01/movies/re...      ...
# 13  http://movies.nytimes.com/2016/01/30/movies/re...      ...
# 14  http://movies.nytimes.com/2016/01/29/movies/re...      ...
# 15  http://movies.nytimes.com/2016/01/29/movies/re...      ...
# 16  http://movies.nytimes.com/2016/01/29/movies/ch...      ...
# 17  http://movies.nytimes.com/2016/01/29/movies/re...      ...
# 18  http://movies.nytimes.com/2016/01/29/movies/re...      ...
# 19  http://movies.nytimes.com/2016/01/29/movies/br...      ...
#
#    multimedia.resource.type  multimedia.resource.width nyt_movie_id  \
# 0                 thumbnail                         75       571949
# 1                 thumbnail                         75       445821
# 2                 thumbnail                         75       426724
# 3                 thumbnail                         75       480845
# 4                 thumbnail                         75       461209
# 5                 thumbnail                         75       479912
# 6                 thumbnail                         75       480202
# 7                 thumbnail                         75       571354
# 8                 thumbnail                         75       571611
# 9                 thumbnail                         75       480989
# 10                thumbnail                         75       478194
# 11                thumbnail                         75       481165
# 12                thumbnail                         75       572249
# 13                thumbnail                         75       571463
# 14                thumbnail                         75       572176
# 15                thumbnail                         75       571933
# 16                thumbnail                         75       478532
# 17                thumbnail                         75       571725
# 18                thumbnail                         75       572257
# 19                thumbnail                         75       572062
#
#    opening_date  publication_date  \
# 0    2016-03-04        2016-03-04
# 1    2016-02-12        2016-02-12
# 2    2016-02-12        2016-02-12
# 3    2016-02-05        2016-02-05
# 4    2016-02-05        2016-02-05
# 5    2016-02-05        2016-02-05
# 6    2016-02-05        2016-02-05
# 7    2016-02-05        2016-02-05
# 8    2016-02-05        2016-02-05
# 9    2016-02-05        2016-02-05
# 10   2016-02-05        2016-02-05
# 11   2015-02-03        2016-02-03
# 12   2016-01-29        2016-02-01
# 13   2016-01-29        2016-01-30
# 14   2016-01-29        2016-01-29
# 15   2016-01-29        2016-01-29
# 16   2016-01-29        2016-01-29
# 17   2016-01-29        2016-01-29
# 18   2016-01-29        2016-01-29
# 19   2016-01-29        2016-01-29
#
#                                          related_urls  \
# 0   [{u'url': u'http://movies.nytimes.com/movie/57...
# 1   [{u'url': u'http://movies.nytimes.com/movie/44...
# 2   [{u'url': u'http://movies.nytimes.com/movie/42...
# 3   [{u'url': u'http://movies.nytimes.com/movie/48...
# 4   [{u'url': u'http://movies.nytimes.com/movie/46...
# 5   [{u'url': u'http://movies.nytimes.com/movie/47...
# 6   [{u'url': u'http://movies.nytimes.com/movie/48...
# 7   [{u'url': u'http://movies.nytimes.com/movie/57...
# 8   [{u'url': u'http://movies.nytimes.com/movie/57...
# 9   [{u'url': u'http://movies.nytimes.com/movie/48...
# 10  [{u'url': u'http://movies.nytimes.com/movie/47...
# 11  [{u'url': u'http://movies.nytimes.com/movie/48...
# 12  [{u'url': u'http://movies.nytimes.com/movie/57...
# 13  [{u'url': u'http://movies.nytimes.com/movie/57...
# 14  [{u'url': u'http://movies.nytimes.com/movie/57...
# 15  [{u'url': u'http://movies.nytimes.com/movie/57...
# 16  [{u'url': u'http://movies.nytimes.com/movie/47...
# 17  [{u'url': u'http://movies.nytimes.com/movie/57...
# 18  [{u'url': u'http://movies.nytimes.com/movie/57...
# 19  [{u'url': u'http://movies.nytimes.com/movie/57...
#
#                            seo_name                        sort_name  \
# 0                          Zootopia                         Zootopia
# 1                       Zoolander-2                      Zoolander 2
# 2                          Deadpool                         Deadpool
# 3                      Hail-Caesar-                    Hail, Caesar!
# 4   Pride-and-Prejudice-and-Zombies  Pride and Prejudice and Zombies
# 5                     Fort-Buchanan                    Fort Buchanan
# 6          Eisenstein-in-Guanajuato         Eisenstein in Guanajuato
# 7                        Southbound                       Southbound
# 8                          The-Pack                        Pack, The
# 9                        Tumbledown                       Tumbledown
# 10                       The-Choice                      Choice, The
# 11                             Rams                             Rams
# 12                    Saala-Khadoos                    Saala Khadoos
# 13            Fifty-Shades-of-Black            Fifty Shades of Black
# 14                        JeruZalem                        JeruZalem
# 15                       Lazer-Team                       Lazer Team
# 16                 The-Finest-Hours                Finest Hours, The
# 17               Rabin-The-Last-Day              Rabin, The Last Day
# 18   Requiem-for-the-American-Dream   Requiem for the American Dream
# 19                  Kung-Fu-Panda-3                  Kung Fu Panda 3
#
#                                         summary_short thousand_best
# 0   As the first rabbit police officer in Zootopia...             0
# 1   If you took away the extravagantly gaudy trapp...             0
# 2   Jokes and bullets are tossed like confetti in ...             0
# 3   Joel and Ethan Coen meander in and around thei...             0
# 4   In this undead ravishing of the Jane Austen no...             0
# 5   Benjamin Crotty&rsquo;s film, set at a French ...             0
# 6   This comedic fantasy from Peter Greenaway abou...             0
# 7   This anthology film, by the directors Roxanne ...             0
# 8   Nick Robertson&rsquo;s Australian film, set on...             0
# 9   Rebecca Hall plays the young grieving widow of...             0
# 10  Based on a book by Nicholas Sparks, the film s...             0
# 11  The sources of the bad blood are never specifi...             0
# 12  With a rawness that dovetails with the role, t...             0
# 13  This satire starring and co-written by Marlon ...             0
# 14  A different perspective on a dream vacation to...             0
# 15  Four small-town idiots accidentally end up in ...             0
# 16  Based on a real-life 1952 rescue of men aboard...             0
# 17  Mr. Gitai&rsquo;s new film delves into the inc...             0
# 18  In the documentary &ldquo;Requiem for the Amer...             0
# 19  The film&rsquo;s central character, voiced by ...             0
#
# [20 rows x 23 columns]>

# %%
## print a data frame with just the title, movie id and critics pick status
movies_df[["display_title", "nyt_movie_id", "critics_pick"]]
# Out:
#                                      display_title  nyt_movie_id  critics_pick
# 0                         I Touched All Your Stuff        481363             0
# 1                               7 Chinese Brothers        480152             0
# 2                                            Fever        479630             0
# 3                             Que Horas Ela Volta?        478698             0
# 4                                    The Great Man        480680             1
# 5                                 Mistress America        478468             1
# 6                                  Tom at the Farm        472150             1
# 7                                A Sinner in Mecca        481622             1
# 8                             Contracted: Phase II        481518             0
# 9                                    Dirty Weekend        479330             0
# 10              Steve Jobs: The Man in the Machine        478955             0
# 11                                    Dragon Blade        478482             0
# 12                        The Transporter Refueled        477735             0
# 13                                           Blind        472844             1
# 14                                 La Jaula de Oro        471823             1
# 15                                  Theo and Chloe        462544             0
# 16                                    Before We Go        450276             0
# 17  The Black Panthers: Vanguard of the Revolution        479844             1
# 18                                           Creep        476127             0
# 19                             A Walk in the Woods        446308             0

# %% [markdown]
# ## Repeat this process with a new API

# %% [markdown]
# ## Extra credit:
# There are several ways to convert to a python data frame. Find another!

# %% [markdown]
# ## New to APIs? What to know more about RESTful APIs?
# Check out this great tutorial
# https://www.codecademy.com/courses/python-intermediate-en-6zbLp/3/5?curriculum_id=50ecbb00306689057a000188
